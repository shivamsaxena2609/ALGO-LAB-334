# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamsaxena2609/ALGO-LAB-334/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances


graph = {}

n = int(input("Enter number of nodes: "))

print("Enter node names:")
nodes = input().split()

for node in nodes:
    graph[node] = {}

e = int(input("Enter number of edges: "))

for _ in range(e):
    u, v, w = input().split()
    graph[u][v] = int(w)

start = input("Enter starting node: ")

result = dijkstra(graph, start)

for node in result:
    print(f"{start} → {node} = {result[node]}")
# Out:
# Enter number of nodes: 4
# Enter node names:
# A B C D
# Enter number of edges: 5
# A B 3
# A D 7
# B C 2
# C D 1
# D A 2
# Enter starting node: A
# A → A = 0
# A → B = 3
# A → C = 5
# A → D = 6

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []
    parent = {}

    for node in graph:
        distances[node] = float('inf')
        parent[node] = None

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                parent[neighbor] = min_node

    return distances, parent


def get_path(parent, node):
    path = []
    while node is not None:
        path.append(node)
        node = parent[node]
    return path[::-1]


graph = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10},
    'C': {'A': 2, 'B': 5, 'D': 3},
    'D': {'B': 10, 'C': 3}
}

result, parent = dijkstra(graph, 'A')

for node in result:
    path = get_path(parent, node)
    print("Path from A to", node, "=", " -> ".join(path), "| Distance =", result[node])
# Out:
# Path from A to A = A | Distance = 0
# Path from A to B = A -> B | Distance = 4
# Path from A to C = A -> C | Distance = 2
# Path from A to D = A -> C -> D | Distance = 5

# %%
graph = {
    'A': {'B': 4, 'C': 2, 'E': 7},
    'B': {'A': 4, 'C': 5, 'D': 10, 'F': 6},
    'C': {'A': 2, 'B': 5, 'D': 3},
    'D': {'B': 10, 'C': 3, 'F': 2},
    'E': {'A': 7, 'F': 3},
    'F': {'B': 6, 'D': 2, 'E': 3}
}

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []
    parent = {}

    for node in graph:
        distances[node] = float('inf')
        parent[node] = None

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                parent[neighbor] = min_node

    return distances, parent


def run_test(graph, source):
    result, parent = dijkstra(graph, source)

    print("\nSource =", source)
    for node in result:
        print(source, "→", node, "=", result[node])


graph = {
    'A': {'B': 4, 'C': 2, 'E': 7},
    'B': {'A': 4, 'C': 5, 'D': 10, 'F': 6},
    'C': {'A': 2, 'B': 5, 'D': 3},
    'D': {'B': 10, 'C': 3, 'F': 2},
    'E': {'A': 7, 'F': 3},
    'F': {'B': 6, 'D': 2, 'E': 3}
}

sources = ['A', 'B', 'C', 'D', 'E', 'F']

for s in sources:
    run_test(graph, s)
# Out:
# Source = A
# A → A = 0
# A → B = 4
# A → C = 2
# A → D = 5
# A → E = 7
# A → F = 7
#
# Source = B
# B → A = 4
# B → B = 0
# B → C = 5
# B → D = 8
# B → E = 9
# B → F = 6
#
# Source = C
# C → A = 2
# C → B = 5
# C → C = 0
# C → D = 3
# C → E = 8
# C → F = 5
#
# Source = D
# D → A = 5
# D → B = 8
# D → C = 3
# D → D = 0
# D → E = 5
# D → F = 2
#
# Source = E
# E → A = 7
# E → B = 9
# E → C = 8
# E → D = 5
# E → E = 0
# E → F = 3
#
# Source = F
# F → A = 7
# F → B = 6
# F → C = 5
# F → D = 2
# F → E = 3
# F → F = 0
